# %%
# %pip install pandasgui

# %%
import pandas as pd
import numpy as np

data = pd.read_csv(r"C:\Users\conno\workspace\projects\ufc_predictive_model\ufc-fighters-statistics.csv")

print(data.isnull().sum)
# Out:
# <bound method DataFrame.sum of        name  nickname   wins  losses  draws  height_cm  weight_in_kg  \
# 0     False      True  False   False  False      False         False
# 1     False      True  False   False  False      False         False
# 2     False     False  False   False  False      False         False
# 3     False     False  False   False  False      False         False
# 4     False      True  False   False  False      False         False
# ...     ...       ...    ...     ...    ...        ...           ...
# 4104  False     False  False   False  False       True         False
# 4105  False      True  False   False  False      False         False
# 4106  False      True  False   False  False       True         False
# 4107  False      True  False   False  False      False         False
# 4108  False     False  False   False  False      False         False
#
#       reach_in_cm  stance  date_of_birth  \
# 0            True    True           True
# ...

# %%
data.head()
# Out:
#                  name                  nickname  wins  losses  draws  \
# 0        Rex Richards                       NaN     7       2      0
# 1        Luana Santos                       NaN     6       1      0
# 2  Cortavious Romious  Are You Not Entertained?     7       2      0
# 3         Danny Silva                   El Puma     8       1      0
# 4       Angel Pacheco                       NaN     7       2      0
#
#    height_cm  weight_in_kg  reach_in_cm    stance date_of_birth  \
# 0     195.58        120.20          NaN       NaN           NaN
# 1     167.64         56.70       170.18  Orthodox    2000-04-16
# 2     162.56         61.23       172.72  Southpaw    1994-01-06
# 3     180.34         65.77       177.80    Switch    1997-01-30
# 4     172.72         65.77       177.80  Orthodox    1992-01-13
#
#    significant_strikes_landed_per_minute  significant_striking_accuracy  \
# 0                                  17.65                           58.0
# ...

# %%
data.describe()
# Out:
#               wins       losses        draws    height_cm  weight_in_kg  \
# count  4109.000000  4109.000000  4109.000000  3812.000000   4022.000000
# mean     12.360672     5.722073     0.264298   178.234439     77.395405
# std       9.376023     5.104569     0.822483     8.889213     17.988389
# min       0.000000     0.000000     0.000000   152.400000     47.630000
# 25%       7.000000     2.000000     0.000000   172.720000     65.770000
# 50%      11.000000     4.000000     0.000000   177.800000     77.110000
# 75%      17.000000     8.000000     0.000000   185.420000     83.910000
# max     253.000000    83.000000    11.000000   226.060000    349.270000
#
#        reach_in_cm  significant_strikes_landed_per_minute  \
# count  2183.000000                            4109.000000
# mean    181.803729                               2.442100
# std      10.679990                               1.996586
# min     147.320000                               0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4109 entries, 0 to 4108
# Data columns (total 18 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   name                                          4109 non-null   object
#  1   nickname                                      2255 non-null   object
#  2   wins                                          4109 non-null   int64
#  3   losses                                        4109 non-null   int64
#  4   draws                                         4109 non-null   int64
#  5   height_cm                                     3812 non-null   float64
#  6   weight_in_kg                                  4022 non-null   float64
#  7   reach_in_cm                                   2183 non-null   float64
#  8   stance                                        3287 non-null   object
# ...

# %%
df = data.dropna(subset=['reach_in_cm', 'height_cm', 'stance', 'date_of_birth'])
print(df.isna().sum())
# Out:
# name                                              0
# nickname                                        658
# wins                                              0
# losses                                            0
# draws                                             0
# height_cm                                         0
# weight_in_kg                                      0
# reach_in_cm                                       0
# stance                                            0
# date_of_birth                                     0
# significant_strikes_landed_per_minute             0
# significant_striking_accuracy                     0
# significant_strikes_absorbed_per_minute           0
# significant_strike_defence                        0
# average_takedowns_landed_per_15_minutes           0
# takedown_accuracy                                 0
# takedown_defense                                  0
# average_submissions_attempted_per_15_minutes      0
# dtype: int64

# %%
print(df['stance'].value_counts())
# Out:
# stance
# Orthodox       1610
# Southpaw        386
# Switch          164
# Open Stance       2
# Name: count, dtype: int64

# %%
print(df.nunique())
# Out:
# name                                            2160
# nickname                                        1251
# wins                                              48
# losses                                            25
# draws                                              7
# height_cm                                         22
# weight_in_kg                                      40
# reach_in_cm                                       27
# stance                                             4
# date_of_birth                                   1895
# significant_strikes_landed_per_minute            612
# significant_striking_accuracy                     70
# significant_strikes_absorbed_per_minute          647
# significant_strike_defence                        69
# average_takedowns_landed_per_15_minutes          481
# takedown_accuracy                                 82
# takedown_defense                                  90
# average_submissions_attempted_per_15_minutes     612
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Calculating the median number of wins
median_wins = df['wins'].median()

# Categorizng win rates
df['win_rate_cat'] = pd.cut(df['wins'], bins=[-1, median_wins, df['wins'].max()], labels=['Low Win Rate', 'High Win Rate'])
# Out:
# C:\Users\conno\AppData\Local\Temp\ipykernel_11148\693060421.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['win_rate_cat'] = pd.cut(df['wins'], bins=[-1, median_wins, df['wins'].max()], labels=['Low Win Rate', 'High Win Rate'])

# %%
corr_df = df.drop(columns=['name', 'nickname'])

corr_matrix = corr_df.corr()

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 3
#       1 corr_df = df.drop(columns=['name', 'nickname'])
# ----> 3 corr_matrix = corr_df.corr()
#       5 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
#       6 plt.show()
#
# File c:\Users\conno\anaconda3\envs\ufc_predictive_model\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\conno\anaconda3\envs\ufc_predictive_model\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# ...
